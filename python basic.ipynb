# %% [raw]
# 1.What is Python, and why is it popular ?
# -Python is a high-level, easy-to-read programming language used for web development, data analysis, AI, and more.
# Its popularity comes from its simplicity, vast libraries, and strong community support.
#
# 2. What is an interpreter in Python ?
# -An interpreter in Python is a program that reads and executes Python code line by line, converting the high-level instructions you write (in .py files) into machine-level instructions that the computer can understand and execute.
#
# 3.What are pre-defined keywords in Python ?
# -Pre-defined keywords in Python are reserved words that have special meanings and are part of the Python language syntax. These words cannot be used as identifiers (like variable names, function names, or class names) because they are used to define the structure and flow of Python programs.
#
# 4.Can keywords be used as variable names ?
# -No, keywords cannot be used as variable names in most programming languages.
#
# 5.What is mutability in Python ?
# - Mutability in Python refers to whether or not an object can be changed after it is created.
# Mutable objects:List,dict,set
#
# 6. Why are lists mutable, but tuples are immutable?
# -In Python, lists are mutable and tuples are immutable because of intentional design decisions based on their intended use cases and performance considerations.
# tuples are mutable
# Designed for change: Lists are meant to store collections of items that can be modified—like adding, removing, or changing elements.
#
# Common use case: When working with data that may change over time (e.g., appending user inputs, sorting data), mutability is helpful.
#
# Implementation: Lists in Python use dynamic arrays under the hood, allowing in-place modification without needing to reallocate memory constantly.
# tuples are imutable
# Designed for fixed data: Tuples are meant to represent fixed collections of values—like coordinates, RGB color values, or function return groups.
#
# Safer and hashable: Since they can’t be changed, tuples can be used as dictionary keys or stored in sets (if they contain only hashable elements).
#
# Optimization: Because they’re immutable, Python can optimize memory and performance for tuples more aggressively than for lists.
#
# 7. What is the difference between “==” and “is” operators in Python ?
# -In Python, == and is are both comparison operators, but they serve different purposes:
#
# 1. == (Equality Operator)
# Checks if the values of two variables are equal.
#
# It compares the contents of the variables.
#
# python
# Copy
# Edit
# a = [1, 2, 3]
# b = [1, 2, 3]
# print(a == b)  # True, because their contents are the same.

# %% [raw]
# 8.What are logical operators in Python ?
# -Logical operators in Python are used to combine conditional statements (expressions that evaluate to True or False). They are primarily used in control flow statements like if, while, etc.
# there are 3 operator in python and,or,not.
#
# 9. What is type casting in Python ?
# -Type casting in Python refers to the process of converting a variable from one data type to another. This is often necessary when you need to perform operations involving different data types or when you need to ensure a specific type of data format for an operation.
#
# There are two types of type casting:
#
# Implicit Type Casting (Type Coercion): This occurs automatically when Python converts one data type to another without the programmer's intervention. It usually happens wh
#
# 11.en you perform operations with mixed data types. For example, if you add an integer and a float, Python automatically converts the integer to a float before performing the operation.
# Type casting in Python refers to the process of converting a variable from one data type to another. This is often necessary when you need to perform operations involving different data types or when you need to ensure a specific type of data format for an operation.
#
# Explicit Type Casting: This is when you manually convert a variable from one data type to another using Python's built-in functions. You use specific functions like int(), float(), str(), etc., to explicitly cast between types.
#
# 10.What is the difference between implicit and explicit type casting  ?
# -The difference between implicit and explicit type casting (also called type conversion) in programming lies in how the conversion between data types is handled:
#
# 1. Implicit Type Casting (Automatic Type Conversion):
# This is automatically done by the compiler without the programmer’s intervention.
#
# It happens when the data type of a variable can be automatically converted to a wider or compatible type without loss of data.
#
# No explicit syntax is needed; the compiler decides when the conversion is safe.
#
# Typically happens when converting smaller data types
#  Explicit Type Casting (Manual Type Conversion):
# This requires the programmer's explicit intervention to convert one data type to another.
#
# It is used when the conversion is not automatically possible or when the programmer wants to force the conversion, even if it may cause loss of data.
#
# In most languages, explicit casting is done using casting operators or methods.
#
# 11. What is the purpose of conditional statements in Python ?
# - Conditional statements in Python are used to control the flow of a program based on certain conditions. They allow you to execute specific blocks of code only if a given condition is true or false. This is essential for making decisions in your program.
#
# The main types of conditional statements in Python are:
#
# if statement: This runs a block of code if the condition is true.
#
# python
# Copy
# Edit
# if condition:
#     # Execute this block if condition is True
# elif (else if) statement: This allows you to check multiple conditions. If the initial if condition is false, it checks additional conditions.
#
# python
# Copy
# Edit
# if condition1:
#     # Execute if condition1 is True
# elif condition2:
#     # Execute if condition2 is True
# else statement: This runs a block of code if all previous conditions are false.
#
# python
# Copy
# Edit
# if condition:
#     # Execute if condition is True
# else:
#     # Execute if condition is False
# Example:
# python
# Copy
# Edit
# age = 20
#
# if age >= 18:
#     print("You are an adult.")
# else:
#     print("You are a minor.")
# In this example:
#
# If age is 18 or more, it prints "You are an adult."
#
# If age is less than 18, it prints "You are a minor."
#
# Purpose:
# Decision-making: Conditional statements enable programs to make decisions based on inputs, user choices, or variables.
#
# Flexibility: They allow different paths of execution, depending on the state of the program.
#
# Control flow: Helps structure the flow of execution in the program.
#
# They are crucial for handling scenarios where different outcomes are required under varying conditions.
#
# 12.How does the elif statement work ?
# -The elif statement in Python is short for "else if" and is used to check multiple conditions in a sequence. It comes after an if statement and before an optional else statement.he elif allows you to check for multiple conditions without nesting multiple if statements, making the code cleaner and more readable.
#
# 13. What is the difference between for and while loops ?
# -The main difference between for and while loops lies in how they control the flow of iteration.
#
# For Loop:
#
# A for loop is generally used when the number of iterations is known beforehand or is based on a sequence (like a list, range, etc.).
#
# It has a definite start, condition, and increment/decrement step built into its structure.
#
# Syntax:
#
# python
# Copy
# Edit
# for i in range(5):  # loops through values 0, 1, 2, 3, 4
#     print(i)
# While Loop:
#
# A while loop is used when the number of iterations is not known in advance. It continues running as long as a specified condition is true.
#
# The condition is checked before each iteration, and the loop runs until the condition becomes false.
#
# Syntax:
#
# python
# Copy
# Edit
# i = 0
# while i < 5:  # loop runs as long as i is less than 5
#     print(i)
#     i += 1  # increment i after each iteration
# Key Differences:
# For loop is more compact and used when the number of iterations is known or the loop iterates over a sequence.
#
# While loop is more flexible and is used when you don’t know the number of iterations ahead of time but want to loop as long as a condition is true.
#
#
# 14.Describe a scenario where a while loop is more suitable than a for loop.
# -A while loop is more suitable than a for loop when you don’t know in advance how many iterations you’ll need, or when you want the loop to continue based on a condition that may change dynamically during execution.
#
# Example Scenario:
#
# Suppose you are building a program that asks a user to input their password repeatedly until they enter the correct one. In this case, you don’t know how many attempts the user will need, so a while loop would be more appropriate.
#
# python
# Copy
# Edit
# correct_password = "secure123"
# user_input = ""
#
# while user_input != correct_password:
#     user_input = input("Please enter your password: ")
#     if user_input != correct_password:
#         print("Incorrect password, try again.")
# In this example, the loop continues indefinitely (or until the user enters the correct password) without a predefined number of iterations, which makes the while loop ideal for the situation.

# %%
1.# Write a Python program to print "Hello, World!?
print("Hello, World!")
# Out:
# Hello, World!

# %%
2.# Write a Python program that displays your name and age
name = "alice"
age = "25"
print("name")
print("age")
# Out:
# name
# age

# %% [raw]
# 3.Write code to print all the pre-defined keywords in Python using the keyword library
